# %% [markdown]
# <a href="https://colab.research.google.com/github/sravyamullapudi26/code_alpha_data_SCience/blob/main/Iris_Flower_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import Libraries
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Step 2: Load the Dataset
# You can load it from Scikit-learn
data = load_iris()
X = data.data  # Feature matrix
y = data.target  # Target labels

# Display feature names and target classes
print("Feature Names:", data.feature_names)
print("Target Classes:", data.target_names)

# Convert to DataFrame for better readability
df = pd.DataFrame(X, columns=data.feature_names)
df['Species'] = y
print(df.head())

# Step 3: Explore the Dataset
# Basic statistics of the dataset
print(df.describe())

# Visualize the data
sns.pairplot(df, hue="Species", palette="husl")
plt.show()

# Step 4: Preprocess the Data
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 5: Train the Model
# Using Random Forest Classifier
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Step 6: Evaluate the Model
# Predict on test data
y_pred = model.predict(X_test)

# Accuracy and performance metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Step 7: Make Predictions
# Example: Predicting on new input data
new_data = [[5.1, 3.5, 1.4, 0.2]]  # Sample input
prediction = model.predict(new_data)
print("Predicted Class:", data.target_names[prediction[0]])
# Out:
# Feature Names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target Classes: ['setosa' 'versicolor' 'virginica']
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# ...
